# %%
a = 'Ramesh'
b = 'S'+ a[1:]
print(b)
# Out:
# Samesh

# %%
a = '   Hani   '
print(a.strip())  #removes space
print(a.lstrip()) #removes space from left
print(a.rstrip()) #removes space from right
# Out:
# Hani
# Hani
#    Hani

# %%
a= 'hani'
print(a.capitalize())  #capitalizes inital letter
# Out:
# Hani

# %%
a = 'hani'
print(a.swapcase())  #converts upper to lower amd vice versa
# Out:
# HANI

# %%
a = 'HANI'
print(a.swapcase())
# Out:
# hani

# %%
a = 'Hani'
print(a.startswith('H'))  #returns true if given letter matches the initial letter
print(a.endswith('h'))    #returns true if given letter matches the last letter
# Out:
# True
# False

# %%
a = 'Hani'
print(a.replace(a, 'haniiiiii'))   #replaces old string with given new string
# Out:
# haniiiiii

# %%
a = 'Python'
print(a.find('s'))
print(a.index('P'))
# Out:
# -1
# 0

# %%
a = 'Data science in python'
print(a.find('Data'))
print(a.index('in'))
# Out:
# 0
# 13

# %%
a = 'Doxpro Robotics'

#converts string to list
print(a.split(',')) 
print(a.split(' ')) 
print(a.split('o')) 
print(a.split('t'))
# Out:
# ['Doxpro Robotics']
# ['Doxpro', 'Robotics']
# ['D', 'xpr', ' R', 'b', 'tics']
# ['Doxpro Robo', 'ics']

# %%
a = ['Doxpro' , 'Robotics']
b = ' '.join(a)      #converts list to string
print(b)
print(type(b))
# Out:
# Doxpro Robotics
# <class 'str'>

# %%
url = 'https://www.Kaggle.com/login'
new_url = url.removeprefix('https://')
print(new_url)
# Out:
# www.Kaggle.com/login

# %%
url = 'Kaggle.com'
new_url = url.removesuffix('.com')
print(new_url)
# Out:
# Kaggle

# %%
a = 'Data science in python'
print(a.replace(' ', '-'))
# Out:
# Data-science-in-python

# %%
a = 'Data science in python'
b = a.split(' ')
b = '-'.join(b)
print(b)
# Out:
# Data-science-in-python

# %%
a = 'HA_NI'
print(a.isupper())
print(a.islower())
print(a.isalnum())
# Out:
# True
# False
# False

# %%
a = 'https://www.Kaggle.com/Dataset'
print(f'URL:       {a}')  
print(f'Protocal: ', a[:8])
print(f'Domain:   ', a[8:22])
print(f'Page:     ', a[23:])
# Out:
# URL:       https://www.Kaggle.com/Dataset
# Protocal:  https://
# Domain:    www.Kaggle.com
# Page:      Dataset

# %%
a = 'Haaaaaniiii'
print(a.count('a'))
# Out:
# 5

# %%
a = 'Python'
print(a.ljust(10,'*'))
print(a.rjust(10,'*'))
# Out:
# Python****
# ****Python

# %%
a = input('Enter a url:')
print('URL:'.ljust(10), a)
b = a.split('/')
print('Protocal: '.ljust(10),b[0])
print('Domain: '.ljust(10),b[2])
print('Page: '.ljust(10),b[3])
# Out:
# URL:       https://www.flipkart.com/Dashboard
# Protocal:  https:
# Domain:    www.flipkart.com
# Page:      Dashboard

# %%
a = 'hani'
name = a[::-1]
if a == name :
    print(f'{a} is a palindrome')

else :
    print(f'{a} is not a palindrome')
# Out:
# hani is not a palindrome

# %%
a = input('Enter a phone number: ')
b = a.replace(a[0:6],'*',)
c = b.rjust(11,'*')
print(c)
# Out:
# *******3556
