# %%
a = 'Naresh'
for i in a:
    print(i)
# Out:
# N
# a
# r
# e
# s
# h

# %%
for i in range(1,11) :
    if i%2 == 0:
        print(i)
# Out:
# 2
# 4
# 6
# 8
# 10

# %%
for i in range(1,11):
    if i%2 == 0:
        print('Even:', i)

    else:
        print('Odd: ', i)
# Out:
# Odd:  1
# Even: 2
# Odd:  3
# Even: 4
# Odd:  5
# Even: 6
# Odd:  7
# Even: 8
# Odd:  9
# Even: 10

# %%
for i in range(1,11):
    print('Square:', i*i)
# Out:
# Square: 1
# Square: 4
# Square: 9
# Square: 16
# Square: 25
# Square: 36
# Square: 49
# Square: 64
# Square: 81
# Square: 100

# %%
a = 'Yahoo.com'
for i in a:
    if '.' in i:
        break
    print(i,end='')
# Out:
# Yahoo

# %%
for i in range(5,0,-1):   #(start, stop, step)
    print('* '*i)
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *

# %%
for i in range(6) :
    print('* '*i)
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
for i in range(5,0,-1):
    print('* '*i)
for i in range(2,6):
    print('* '*i)
# Out:
# * * * * *
# * * * *
# * * *
# * *
# *
# * *
# * * *
# * * * *
# * * * * *

# %%
a = 1
for i in range(6,0,-1):
    print(' '*i+'*'*a,end= ' ')
    a+=2
    print()
# Out:
#       *
#      ***
#     *****
#    *******
#   *********
#  ***********
